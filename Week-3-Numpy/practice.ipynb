# %%
import numpy as np
from imageio import imread
import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))
pic = imread('./wifire/spacee.jpg')
plt.imshow(pic)

# %%
rows, cols, layers = pic.shape
filter = pic > 200
pic[filter] = 255
plt.figure(figsize=(15,15))
plt.imshow(pic)

# %%
pic = imread('./wifire/spacee.jpg')
rows, cols, layers = pic.shape
center_row, center_col = rows / 2, cols / 2
r = rows - center_row

X, Y = np.ogrid[:rows, :cols]
center_dist_x = X - center_row
center_dist_y = Y - center_col
dist = center_dist_x ** 2 + center_dist_y ** 2
round_filter = dist > r ** 2
upper_filter = X > center_row
pic[round_filter & upper_filter] = 0

plt.figure(figsize=(15,15))
plt.imshow(pic)

# %%
pic = imread('./wifire/spacee.jpg')
red_mask   = pic[:, : ,0] < 150
green_mask = pic[:, : ,1] > 100
blue_mask  = pic[:, : ,2] < 100
pic[red_mask & red_mask & blue_mask] = 0

plt.figure(figsize=(15,15))
plt.imshow(pic)
